# %%
import os
import csv
import numpy as np
import matplotlib.pyplot as plt

def export_dataset(dataset, flag_value):
    np.save(f"{flag_value}_RPM_raw.npy", dataset)
    print(f"Dataset shape: {dataset.shape}")

def session_2d_histogram(ts_mask, sizes_mask):
    data_values = sizes_mask
    hist, bin_edges = np.histogram(data_values, bins=256, range=(0, 255))
    return hist

def traffic_csv_converter(file_path):
    print("Running on " + file_path)
    session_data = {'R': [], 'T': []}
    counter = 0

    with open(file_path, 'r') as csv_file:
        reader = csv.reader(csv_file)
        for row in reader:
            # if counter >= 2e5:
            #     break
            can_id = row[1]
            length = int(row[2])
            data_values = [int(x, 16) for x in row[3:3+length]]
            flag_value = row[-1]

            if flag_value not in session_data:
                continue

            ts = float(row[0])
            h = session_2d_histogram(ts, data_values)

            session_data[flag_value].append(h)
            
            counter += 1
            if counter % 100 == 0:
                print(f"Processed {counter} rows")

    for flag_value, dataset in session_data.items():
        if dataset:
            session_array = np.asarray(dataset)
            export_dataset(session_array, flag_value)

def plot_histogram(data, bins=10):
    plt.hist(data, bins=bins, range=(0, 255), alpha=0.75)
    plt.title('Histogram of Data Values')
    plt.xlabel('Data Value')
    plt.ylabel('Frequency')
    plt.show()

if __name__ == '__main__':
    input_file_path = r"RPM_dataset.csv"
    traffic_csv_converter(input_file_path)
# Out:
# Running on RPM_dataset.csv
# Processed 100 rows
# Processed 200 rows
# Processed 300 rows
# Processed 400 rows
# Processed 500 rows
# Processed 600 rows
# Processed 700 rows
# Processed 800 rows
# Processed 900 rows
# Processed 1000 rows
# Processed 1100 rows
# Processed 1200 rows
# Processed 1300 rows
# Processed 1400 rows
# Processed 1500 rows
# Processed 1600 rows
# Processed 1700 rows
# Processed 1800 rows
# Processed 1900 rows
# Processed 2000 rows
# Processed 2100 rows
# Processed 2200 rows
# Processed 2300 rows
# Processed 2400 rows
# Processed 2500 rows
# Processed 2600 rows
# Processed 2700 rows
# Processed 2800 rows
# Processed 2900 rows
# Processed 3000 rows
# Processed 3100 rows
# Processed 3200 rows
# Processed 3300 rows
# Processed 3400 rows
# Processed 3500 rows
# Processed 3600 rows
# Processed 3700 rows
# Processed 3800 rows
# Processed 3900 rows
# Processed 4000 rows
# Processed 4100 rows
# Processed 4200 rows
# Processed 4300 rows
# Processed 4400 rows
# Processed 4500 rows
# Processed 4600 rows
# Processed 4700 rows
# Processed 4800 rows
# Processed 4900 rows
# Processed 5000 rows
# Processed 5100 rows
# Processed 5200 rows
# Processed 5300 rows
# Processed 5400 rows
# Processed 5500 rows
# Processed 5600 rows
# Processed 5700 rows
# Processed 5800 rows
# Processed 5900 rows
# Processed 6000 rows
# Processed 6100 rows
# Processed 6200 rows
# Processed 6300 rows
# Processed 6400 rows
# Processed 6500 rows
# Processed 6600 rows
# Processed 6700 rows
# Processed 6800 rows
# Processed 6900 rows
# Processed 7000 rows
# Processed 7100 rows
# Processed 7200 rows
# Processed 7300 rows
# Processed 7400 rows
# Processed 7500 rows
# Processed 7600 rows
# Processed 7700 rows
# Processed 7800 rows
# Processed 7900 rows
# Processed 8000 rows
# Processed 8100 rows
# Processed 8200 rows
# Processed 8300 rows
# Processed 8400 rows
# Processed 8500 rows
# Processed 8600 rows
# Processed 8700 rows
# Processed 8800 rows
# Processed 8900 rows
# Processed 9000 rows
# Processed 9100 rows
# Processed 9200 rows
# Processed 9300 rows
# Processed 9400 rows
# Processed 9500 rows
# Processed 9600 rows
# Processed 9700 rows
# Processed 9800 rows
# Processed 9900 rows
# Processed 10000 rows
# Processed 10100 rows
# Processed 10200 rows
# Processed 10300 rows
# Processed 10400 rows
# Processed 10500 rows
# Processed 10600 rows
# Processed 10700 rows
# Processed 10800 rows
# Processed 10900 rows
# Processed 11000 rows
# Processed 11100 rows
# Processed 11200 rows
# Processed 11300 rows
# Processed 11400 rows
# Processed 11500 rows
# Processed 11600 rows
# Processed 11700 rows
# Processed 11800 rows
# Processed 11900 rows
# Processed 12000 rows
# Processed 12100 rows
# Processed 12200 rows
# Processed 12300 rows
# Processed 12400 rows
# Processed 12500 rows
# Processed 12600 rows
# Processed 12700 rows
# Processed 12800 rows
# Processed 12900 rows
# Processed 13000 rows
# Processed 13100 rows
# Processed 13200 rows
# Processed 13300 rows
# Processed 13400 rows
# Processed 13500 rows
# Processed 13600 rows
# Processed 13700 rows
# Processed 13800 rows
# Processed 13900 rows
# Processed 14000 rows
# Processed 14100 rows
# Processed 14200 rows
# Processed 14300 rows
# Processed 14400 rows
# Processed 14500 rows
# Processed 14600 rows
# Processed 14700 rows
# Processed 14800 rows
# Processed 14900 rows
# Processed 15000 rows
# Processed 15100 rows
# Processed 15200 rows
# Processed 15300 rows
# Processed 15400 rows
# Processed 15500 rows
# Processed 15600 rows
# Processed 15700 rows
# Processed 15800 rows
# Processed 15900 rows
# Processed 16000 rows
# Processed 16100 rows
# Processed 16200 rows
# Processed 16300 rows
# Processed 16400 rows
# Processed 16500 rows
# Processed 16600 rows
# Processed 16700 rows
# Processed 16800 rows
# Processed 16900 rows
# Processed 17000 rows
# Processed 17100 rows
# Processed 17200 rows
# Processed 17300 rows
# Processed 17400 rows
# Processed 17500 rows
# Processed 17600 rows
# Processed 17700 rows
# Processed 17800 rows
# Processed 17900 rows
# Processed 18000 rows
# Processed 18100 rows
# Processed 18200 rows
# Processed 18300 rows
# Processed 18400 rows
# Processed 18500 rows
# Processed 18600 rows
# Processed 18700 rows
# Processed 18800 rows
# Processed 18900 rows
# Processed 19000 rows
# Processed 19100 rows
# Processed 19200 rows
# Processed 19300 rows
# Processed 19400 rows
# Processed 19500 rows
# Processed 19600 rows
# Processed 19700 rows
# Processed 19800 rows
# Processed 19900 rows
# Processed 20000 rows
# Processed 20100 rows
# Processed 20200 rows
# Processed 20300 rows
# Processed 20400 rows
# Processed 20500 rows
# Processed 20600 rows
# Processed 20700 rows
# Processed 20800 rows
# Processed 20900 rows
# Processed 21000 rows
# Processed 21100 rows
# Processed 21200 rows
# Processed 21300 rows
# Processed 21400 rows
# Processed 21500 rows
# Processed 21600 rows
# Processed 21700 rows
# Processed 21800 rows
# Processed 21900 rows
# Processed 22000 rows
# Processed 22100 rows
# Processed 22200 rows
# Processed 22300 rows
# Processed 22400 rows
# Processed 22500 rows
# Processed 22600 rows
# Processed 22700 rows
# Processed 22800 rows
# Processed 22900 rows
# Processed 23000 rows
# Processed 23100 rows
# Processed 23200 rows
# Processed 23300 rows
# Processed 23400 rows
# Processed 23500 rows
# Processed 23600 rows
# Processed 23700 rows
# Processed 23800 rows
# Processed 23900 rows
# Processed 24000 rows
# Processed 24100 rows
# Processed 24200 rows
# Processed 24300 rows
# Processed 24400 rows
# Processed 24500 rows
# Processed 24600 rows
# Processed 24700 rows
# Processed 24800 rows
# Processed 24900 rows
# Processed 25000 rows
# Processed 25100 rows
# Processed 25200 rows
# Processed 25300 rows
# Processed 25400 rows
# Processed 25500 rows
# Processed 25600 rows
# Processed 25700 rows
# Processed 25800 rows
# Processed 25900 rows
# Processed 26000 rows
# Processed 26100 rows
# Processed 26200 rows
# Processed 26300 rows
# Processed 26400 rows
# Processed 26500 rows
# Processed 26600 rows
# Processed 26700 rows
# Processed 26800 rows
# Processed 26900 rows
# Processed 27000 rows
# Processed 27100 rows
# Processed 27200 rows
# Processed 27300 rows
# Processed 27400 rows
# Processed 27500 rows
# Processed 27600 rows
# Processed 27700 rows
# Processed 27800 rows
# Processed 27900 rows
# Processed 28000 rows
# Processed 28100 rows
# Processed 28200 rows
# Processed 28300 rows
# Processed 28400 rows
# Processed 28500 rows
# Processed 28600 rows
# Processed 28700 rows
# Processed 28800 rows
# Processed 28900 rows
# Processed 29000 rows
# Processed 29100 rows
# Processed 29200 rows
# Processed 29300 rows
# Processed 29400 rows
# Processed 29500 rows
# Processed 29600 rows
# Processed 29700 rows
# Processed 29800 rows
# Processed 29900 rows
# Processed 30000 rows
# Processed 30100 rows
# Processed 30200 rows
# Processed 30300 rows
# Processed 30400 rows
# Processed 30500 rows
# Processed 30600 rows
# Processed 30700 rows
# Processed 30800 rows
# Processed 30900 rows
# Processed 31000 rows
# Processed 31100 rows
# Processed 31200 rows
# Processed 31300 rows
# Processed 31400 rows
# Processed 31500 rows
# Processed 31600 rows
# Processed 31700 rows
# Processed 31800 rows
# Processed 31900 rows
# Processed 32000 rows
# Processed 32100 rows
# Processed 32200 rows
# Processed 32300 rows
# Processed 32400 rows
# Processed 32500 rows
# Processed 32600 rows
# Processed 32700 rows
# Processed 32800 rows
# Processed 32900 rows
# Processed 33000 rows
# Processed 33100 rows
# Processed 33200 rows
# Processed 33300 rows
# Processed 33400 rows
# Processed 33500 rows
# Processed 33600 rows
# Processed 33700 rows
# Processed 33800 rows
# Processed 33900 rows
# Processed 34000 rows
# Processed 34100 rows
# Processed 34200 rows
# Processed 34300 rows
# Processed 34400 rows
# Processed 34500 rows
# Processed 34600 rows
# Processed 34700 rows
# Processed 34800 rows
# Processed 34900 rows
# Processed 35000 rows
# Processed 35100 rows
# Processed 35200 rows
# Processed 35300 rows
# Processed 35400 rows
# Processed 35500 rows
# Processed 35600 rows
# Processed 35700 rows
# Processed 35800 rows
# Processed 35900 rows
# Processed 36000 rows
# Processed 36100 rows
# Processed 36200 rows
# Processed 36300 rows
# Processed 36400 rows
# Processed 36500 rows
# Processed 36600 rows
# Processed 36700 rows
# Processed 36800 rows
# Processed 36900 rows
# Processed 37000 rows
# Processed 37100 rows
# Processed 37200 rows
# Processed 37300 rows
# Processed 37400 rows
# Processed 37500 rows
# Processed 37600 rows
# Processed 37700 rows
# Processed 37800 rows
# Processed 37900 rows
# Processed 38000 rows
# Processed 38100 rows
# Processed 38200 rows
# Processed 38300 rows
# Processed 38400 rows
# Processed 38500 rows
# Processed 38600 rows
# Processed 38700 rows
# Processed 38800 rows
# Processed 38900 rows
# Processed 39000 rows
# Processed 39100 rows
# Processed 39200 rows
# Processed 39300 rows
# Processed 39400 rows
# Processed 39500 rows
# Processed 39600 rows
# Processed 39700 rows
# Processed 39800 rows
# Processed 39900 rows
# Processed 40000 rows
# Processed 40100 rows
# Processed 40200 rows
# Processed 40300 rows
# Processed 40400 rows
# Processed 40500 rows
# Processed 40600 rows
# Processed 40700 rows
# Processed 40800 rows
# Processed 40900 rows
# Processed 41000 rows
# Processed 41100 rows
# Processed 41200 rows
# Processed 41300 rows
# Processed 41400 rows
# Processed 41500 rows
# Processed 41600 rows
# Processed 41700 rows
# Processed 41800 rows
# Processed 41900 rows
# Processed 42000 rows
# Processed 42100 rows
# Processed 42200 rows
# Processed 42300 rows
# Processed 42400 rows
# Processed 42500 rows
# Processed 42600 rows
# Processed 42700 rows
# Processed 42800 rows
# Processed 42900 rows
# Processed 43000 rows
# Processed 43100 rows
# Processed 43200 rows
# Processed 43300 rows
# Processed 43400 rows
# Processed 43500 rows
# Processed 43600 rows
# Processed 43700 rows
# Processed 43800 rows
# Processed 43900 rows
# Processed 44000 rows
# Processed 44100 rows
# Processed 44200 rows
# Processed 44300 rows
# Processed 44400 rows
# Processed 44500 rows
# Processed 44600 rows
# Processed 44700 rows
# Processed 44800 rows
# Processed 44900 rows
# Processed 45000 rows
# Processed 45100 rows
# Processed 45200 rows
# Processed 45300 rows
# Processed 45400 rows
# Processed 45500 rows
# Processed 45600 rows
# Processed 45700 rows
# Processed 45800 rows
# Processed 45900 rows
# Processed 46000 rows
# Processed 46100 rows
# Processed 46200 rows
# Processed 46300 rows
# Processed 46400 rows
# Processed 46500 rows
# Processed 46600 rows
# Processed 46700 rows
# Processed 46800 rows
# Processed 46900 rows
# Processed 47000 rows
# Processed 47100 rows
# Processed 47200 rows
# Processed 47300 rows
# Processed 47400 rows
# Processed 47500 rows
# Processed 47600 rows
# Processed 47700 rows
# Processed 47800 rows
# Processed 47900 rows
# Processed 48000 rows
# Processed 48100 rows
# Processed 48200 rows
# Processed 48300 rows
# Processed 48400 rows
# Processed 48500 rows
# Processed 48600 rows
# Processed 48700 rows
# Processed 48800 rows
# Processed 48900 rows
# Processed 49000 rows
# Processed 49100 rows
# Processed 49200 rows
# Processed 49300 rows
# Processed 49400 rows
# Processed 49500 rows
# Processed 49600 rows
# Processed 49700 rows
# Processed 49800 rows
# Processed 49900 rows
# Processed 50000 rows
# Processed 50100 rows
# Processed 50200 rows
# Processed 50300 rows
# Processed 50400 rows
# Processed 50500 rows
# Processed 50600 rows
# Processed 50700 rows
# Processed 50800 rows
# Processed 50900 rows
# Processed 51000 rows
# Processed 51100 rows
# Processed 51200 rows
# Processed 51300 rows
# Processed 51400 rows
# Processed 51500 rows
# Processed 51600 rows
# Processed 51700 rows
# Processed 51800 rows
# Processed 51900 rows
# Processed 52000 rows
# Processed 52100 rows
# Processed 52200 rows
# Processed 52300 rows
# Processed 52400 rows
# Processed 52500 rows
# Processed 52600 rows
# Processed 52700 rows
# Processed 52800 rows
# Processed 52900 rows
# Processed 53000 rows
# Processed 53100 rows
# Processed 53200 rows
# Processed 53300 rows
# Processed 53400 rows
# Processed 53500 rows
# Processed 53600 rows
# Processed 53700 rows
# Processed 53800 rows
# Processed 53900 rows
# Processed 54000 rows
# Processed 54100 rows
# Processed 54200 rows
# Processed 54300 rows
# Processed 54400 rows
# Processed 54500 rows
# Processed 54600 rows
# Processed 54700 rows
# Processed 54800 rows
# Processed 54900 rows
# Processed 55000 rows
# Processed 55100 rows
# Processed 55200 rows
# Processed 55300 rows
# Processed 55400 rows
# Processed 55500 rows
# Processed 55600 rows
# Processed 55700 rows
# Processed 55800 rows
# Processed 55900 rows
# Processed 56000 rows
# Processed 56100 rows
# Processed 56200 rows
# Processed 56300 rows
# Processed 56400 rows
# Processed 56500 rows
# Processed 56600 rows
# Processed 56700 rows
# Processed 56800 rows
# Processed 56900 rows
# Processed 57000 rows
# Processed 57100 rows
# Processed 57200 rows
# Processed 57300 rows
# Processed 57400 rows
# Processed 57500 rows
# Processed 57600 rows
# Processed 57700 rows
# Processed 57800 rows
# Processed 57900 rows
# Processed 58000 rows
# Processed 58100 rows
# Processed 58200 rows
# Processed 58300 rows
# Processed 58400 rows
# Processed 58500 rows
# Processed 58600 rows
# Processed 58700 rows
# Processed 58800 rows
# Processed 58900 rows
# Processed 59000 rows
# Processed 59100 rows
# Processed 59200 rows
# Processed 59300 rows
# Processed 59400 rows
# Processed 59500 rows
# Processed 59600 rows
# Processed 59700 rows
# Processed 59800 rows
# Processed 59900 rows
# Processed 60000 rows
# Processed 60100 rows
# Processed 60200 rows
# Processed 60300 rows
# Processed 60400 rows
# Processed 60500 rows
# Processed 60600 rows
# Processed 60700 rows
# Processed 60800 rows
# Processed 60900 rows
# Processed 61000 rows
# Processed 61100 rows
# Processed 61200 rows
# Processed 61300 rows
# Processed 61400 rows
# Processed 61500 rows
# Processed 61600 rows
# Processed 61700 rows
# Processed 61800 rows
# Processed 61900 rows
# Processed 62000 rows
# Processed 62100 rows
# Processed 62200 rows
# Processed 62300 rows
# Processed 62400 rows
# Processed 62500 rows
# Processed 62600 rows
# Processed 62700 rows
# Processed 62800 rows
# Processed 62900 rows
# Processed 63000 rows
# Processed 63100 rows
# Processed 63200 rows
# Processed 63300 rows
# Processed 63400 rows
# Processed 63500 rows
# Processed 63600 rows
# Processed 63700 rows
# Processed 63800 rows
# Processed 63900 rows
# Processed 64000 rows
# Processed 64100 rows
# Processed 64200 rows
# Processed 64300 rows
# Processed 64400 rows
# Processed 64500 rows
# Processed 64600 rows
# Processed 64700 rows
# Processed 64800 rows
# Processed 64900 rows
# Processed 65000 rows
# Processed 65100 rows
# Processed 65200 rows
# Processed 65300 rows
# Processed 65400 rows
# Processed 65500 rows
# Processed 65600 rows
# Processed 65700 rows
# Processed 65800 rows
# Processed 65900 rows
# Processed 66000 rows
# Processed 66100 rows
# Processed 66200 rows
# Processed 66300 rows
# Processed 66400 rows
# Processed 66500 rows
# Processed 66600 rows
# Processed 66700 rows
# Processed 66800 rows
# Processed 66900 rows
# Processed 67000 rows
# Processed 67100 rows
# Processed 67200 rows
# Processed 67300 rows
# Processed 67400 rows
# Processed 67500 rows
# Processed 67600 rows
# Processed 67700 rows
# Processed 67800 rows
# Processed 67900 rows
# Processed 68000 rows
# Processed 68100 rows
# Processed 68200 rows
# Processed 68300 rows
# Processed 68400 rows
# Processed 68500 rows
# Processed 68600 rows
# Processed 68700 rows
# Processed 68800 rows
# Processed 68900 rows
# Processed 69000 rows
# Processed 69100 rows
# Processed 69200 rows
# Processed 69300 rows
# Processed 69400 rows
# Processed 69500 rows
# Processed 69600 rows
# Processed 69700 rows
# Processed 69800 rows
# Processed 69900 rows
# Processed 70000 rows
# Processed 70100 rows
# Processed 70200 rows
# Processed 70300 rows
# Processed 70400 rows
# Processed 70500 rows
# Processed 70600 rows
# Processed 70700 rows
# Processed 70800 rows
# Processed 70900 rows
# Processed 71000 rows
# Processed 71100 rows
# Processed 71200 rows
# Processed 71300 rows
# Processed 71400 rows
# Processed 71500 rows
# Processed 71600 rows
# Processed 71700 rows
# Processed 71800 rows
# Processed 71900 rows
# Processed 72000 rows
# Processed 72100 rows
# Processed 72200 rows
# Processed 72300 rows
# Processed 72400 rows
# Processed 72500 rows
# Processed 72600 rows
# Processed 72700 rows
# Processed 72800 rows
# Processed 72900 rows
# Processed 73000 rows
# Processed 73100 rows
# Processed 73200 rows
# Processed 73300 rows
# Processed 73400 rows
# Processed 73500 rows
# Processed 73600 rows
# Processed 73700 rows
# Processed 73800 rows
# Processed 73900 rows
# Processed 74000 rows
# Processed 74100 rows
# Processed 74200 rows
# Processed 74300 rows
# Processed 74400 rows
# Processed 74500 rows
# Processed 74600 rows
# Processed 74700 rows
# Processed 74800 rows
# Processed 74900 rows
# Processed 75000 rows
# Processed 75100 rows
# Processed 75200 rows
# Processed 75300 rows
# Processed 75400 rows
# Processed 75500 rows
# Processed 75600 rows
# Processed 75700 rows
# Processed 75800 rows
# Processed 75900 rows
# Processed 76000 rows
# Processed 76100 rows
# Processed 76200 rows
# Processed 76300 rows
# Processed 76400 rows
# Processed 76500 rows
# Processed 76600 rows
# Processed 76700 rows
# Processed 76800 rows
# Processed 76900 rows
# Processed 77000 rows
# Processed 77100 rows
# Processed 77200 rows
# Processed 77300 rows
# Processed 77400 rows
# Processed 77500 rows
# Processed 77600 rows
# Processed 77700 rows
# Processed 77800 rows
# Processed 77900 rows
# Processed 78000 rows
# Processed 78100 rows
# Processed 78200 rows
# Processed 78300 rows
# Processed 78400 rows
# Processed 78500 rows
# Processed 78600 rows
# Processed 78700 rows
# Processed 78800 rows
# Processed 78900 rows
# Processed 79000 rows
# Processed 79100 rows
# Processed 79200 rows
# Processed 79300 rows
# Processed 79400 rows
# Processed 79500 rows
# Processed 79600 rows
# Processed 79700 rows
# Processed 79800 rows
# Processed 79900 rows
# Processed 80000 rows
# Processed 80100 rows
# Processed 80200 rows
# Processed 80300 rows
# Processed 80400 rows
# Processed 80500 rows
# Processed 80600 rows
# Processed 80700 rows
# Processed 80800 rows
# Processed 80900 rows
# Processed 81000 rows
# Processed 81100 rows
# Processed 81200 rows
# Processed 81300 rows
# Processed 81400 rows
# Processed 81500 rows
# Processed 81600 rows
# Processed 81700 rows
# Processed 81800 rows
# Processed 81900 rows
# Processed 82000 rows
# Processed 82100 rows
# Processed 82200 rows
# Processed 82300 rows
# Processed 82400 rows
# Processed 82500 rows
# Processed 82600 rows
# Processed 82700 rows
# Processed 82800 rows
# Processed 82900 rows
# Processed 83000 rows
# Processed 83100 rows
# Processed 83200 rows
# Processed 83300 rows
# Processed 83400 rows
# Processed 83500 rows
# Processed 83600 rows
# Processed 83700 rows
# Processed 83800 rows
# Processed 83900 rows
# Processed 84000 rows
# Processed 84100 rows
# Processed 84200 rows
# Processed 84300 rows
# Processed 84400 rows
# Processed 84500 rows
# Processed 84600 rows
# Processed 84700 rows
# Processed 84800 rows
# Processed 84900 rows
# Processed 85000 rows
# Processed 85100 rows
# Processed 85200 rows
# Processed 85300 rows
# Processed 85400 rows
# Processed 85500 rows
# Processed 85600 rows
# Processed 85700 rows
# Processed 85800 rows
# Processed 85900 rows
# Processed 86000 rows
# Processed 86100 rows
# Processed 86200 rows
# Processed 86300 rows
# Processed 86400 rows
# Processed 86500 rows
# Processed 86600 rows
# Processed 86700 rows
# Processed 86800 rows
# Processed 86900 rows
# Processed 87000 rows
# Processed 87100 rows
# Processed 87200 rows
# Processed 87300 rows
# Processed 87400 rows
# Processed 87500 rows
# Processed 87600 rows
# Processed 87700 rows
# Processed 87800 rows
# Processed 87900 rows
# Processed 88000 rows
# Processed 88100 rows
# Processed 88200 rows
# Processed 88300 rows
# Processed 88400 rows
# Processed 88500 rows
# Processed 88600 rows
# Processed 88700 rows
# Processed 88800 rows
# Processed 88900 rows
# Processed 89000 rows
# Processed 89100 rows
# Processed 89200 rows
# Processed 89300 rows
# Processed 89400 rows
# Processed 89500 rows
# Processed 89600 rows
# Processed 89700 rows
# Processed 89800 rows
# Processed 89900 rows
# Processed 90000 rows
# Processed 90100 rows
# Processed 90200 rows
# Processed 90300 rows
# Processed 90400 rows
# Processed 90500 rows
# Processed 90600 rows
# Processed 90700 rows
# Processed 90800 rows
# Processed 90900 rows
# Processed 91000 rows
# Processed 91100 rows
# Processed 91200 rows
# Processed 91300 rows
# Processed 91400 rows
# Processed 91500 rows
# Processed 91600 rows
# Processed 91700 rows
# Processed 91800 rows
# Processed 91900 rows
# Processed 92000 rows
# Processed 92100 rows
# Processed 92200 rows
# Processed 92300 rows
# Processed 92400 rows
# Processed 92500 rows
# Processed 92600 rows
# Processed 92700 rows
# Processed 92800 rows
# Processed 92900 rows
# Processed 93000 rows
# Processed 93100 rows
# Processed 93200 rows
# Processed 93300 rows
# Processed 93400 rows
# Processed 93500 rows
# Processed 93600 rows
# Processed 93700 rows
# Processed 93800 rows
# Processed 93900 rows
# Processed 94000 rows
# Processed 94100 rows
# Processed 94200 rows
# Processed 94300 rows
# Processed 94400 rows
# Processed 94500 rows
# Processed 94600 rows
# Processed 94700 rows
# Processed 94800 rows
# Processed 94900 rows
# Processed 95000 rows
# Processed 95100 rows
# Processed 95200 rows
# Processed 95300 rows
# Processed 95400 rows
# Processed 95500 rows
# Processed 95600 rows
# Processed 95700 rows
# Processed 95800 rows
# Processed 95900 rows
# Processed 96000 rows
# Processed 96100 rows
# Processed 96200 rows
# Processed 96300 rows
# Processed 96400 rows
# Processed 96500 rows
# Processed 96600 rows
# Processed 96700 rows
# Processed 96800 rows
# Processed 96900 rows
# Processed 97000 rows
# Processed 97100 rows
# Processed 97200 rows
# Processed 97300 rows
# Processed 97400 rows
# Processed 97500 rows
# Processed 97600 rows
# Processed 97700 rows
# Processed 97800 rows
# Processed 97900 rows
# Processed 98000 rows
# Processed 98100 rows
# Processed 98200 rows
# Processed 98300 rows
# Processed 98400 rows
# Processed 98500 rows
# Processed 98600 rows
# Processed 98700 rows
# Processed 98800 rows
# Processed 98900 rows
# Processed 99000 rows
# Processed 99100 rows
# Processed 99200 rows
# Processed 99300 rows
# Processed 99400 rows
# Processed 99500 rows
# Processed 99600 rows
# Processed 99700 rows
# Processed 99800 rows
# Processed 99900 rows
# Processed 100000 rows
# Processed 100100 rows
# Processed 100200 rows
# Processed 100300 rows
# Processed 100400 rows
# Processed 100500 rows
# Processed 100600 rows
# Processed 100700 rows
# Processed 100800 rows
# Processed 100900 rows
# Processed 101000 rows
# Processed 101100 rows
# Processed 101200 rows
# Processed 101300 rows
# Processed 101400 rows
# Processed 101500 rows
# Processed 101600 rows
# Processed 101700 rows
# Processed 101800 rows
# Processed 101900 rows
# Processed 102000 rows
# Processed 102100 rows
# Processed 102200 rows
# Processed 102300 rows
# Processed 102400 rows
# Processed 102500 rows
# Processed 102600 rows
# Processed 102700 rows
# Processed 102800 rows
# Processed 102900 rows
# Processed 103000 rows
# Processed 103100 rows
# Processed 103200 rows
# Processed 103300 rows
# Processed 103400 rows
# Processed 103500 rows
# Processed 103600 rows
# Processed 103700 rows
# Processed 103800 rows
# Processed 103900 rows
# Processed 104000 rows
# Processed 104100 rows
# Processed 104200 rows
# Processed 104300 rows
# Processed 104400 rows
# Processed 104500 rows
# Processed 104600 rows
# Processed 104700 rows
# Processed 104800 rows
# Processed 104900 rows
# Processed 105000 rows
# Processed 105100 rows
# Processed 105200 rows
# Processed 105300 rows
# Processed 105400 rows
# Processed 105500 rows
# Processed 105600 rows
# Processed 105700 rows
# Processed 105800 rows
# Processed 105900 rows
# Processed 106000 rows
# Processed 106100 rows
# Processed 106200 rows
# Processed 106300 rows
# Processed 106400 rows
# Processed 106500 rows
# Processed 106600 rows
# Processed 106700 rows
# Processed 106800 rows
# Processed 106900 rows
# Processed 107000 rows
# Processed 107100 rows
# Processed 107200 rows
# Processed 107300 rows
# Processed 107400 rows
# Processed 107500 rows
# Processed 107600 rows
# Processed 107700 rows
# Processed 107800 rows
# Processed 107900 rows
# Processed 108000 rows
# Processed 108100 rows
# Processed 108200 rows
# Processed 108300 rows
# Processed 108400 rows
# Processed 108500 rows
# Processed 108600 rows
# Processed 108700 rows
# Processed 108800 rows
# Processed 108900 rows
# Processed 109000 rows
# Processed 109100 rows
# Processed 109200 rows
# Processed 109300 rows
# Processed 109400 rows
# Processed 109500 rows
# Processed 109600 rows
# Processed 109700 rows
# Processed 109800 rows
# Processed 109900 rows
# Processed 110000 rows
# Processed 110100 rows
# Processed 110200 rows
# Processed 110300 rows
# Processed 110400 rows
# Processed 110500 rows
# Processed 110600 rows
# Processed 110700 rows
# Processed 110800 rows
# Processed 110900 rows
# Processed 111000 rows
# Processed 111100 rows
# Processed 111200 rows
# Processed 111300 rows
# Processed 111400 rows
# Processed 111500 rows
# Processed 111600 rows
# Processed 111700 rows
# Processed 111800 rows
# Processed 111900 rows
# Processed 112000 rows
# Processed 112100 rows
# Processed 112200 rows
# Processed 112300 rows
# Processed 112400 rows
# Processed 112500 rows
# Processed 112600 rows
# Processed 112700 rows
# Processed 112800 rows
# Processed 112900 rows
# Processed 113000 rows
# Processed 113100 rows
# Processed 113200 rows
# Processed 113300 rows
# Processed 113400 rows
# Processed 113500 rows
# Processed 113600 rows
# Processed 113700 rows
# Processed 113800 rows
# Processed 113900 rows
# Processed 114000 rows
# Processed 114100 rows
# Processed 114200 rows
# Processed 114300 rows
# Processed 114400 rows
# Processed 114500 rows
# Processed 114600 rows
# Processed 114700 rows
# Processed 114800 rows
# Processed 114900 rows
# Processed 115000 rows
# Processed 115100 rows
# Processed 115200 rows
# Processed 115300 rows
# Processed 115400 rows
# Processed 115500 rows
# Processed 115600 rows
# Processed 115700 rows
# Processed 115800 rows
# Processed 115900 rows
# Processed 116000 rows
# Processed 116100 rows
# Processed 116200 rows
# Processed 116300 rows
# Processed 116400 rows
# Processed 116500 rows
# Processed 116600 rows
# Processed 116700 rows
# Processed 116800 rows
# Processed 116900 rows
# Processed 117000 rows
# Processed 117100 rows
# Processed 117200 rows
# Processed 117300 rows
# Processed 117400 rows
# Processed 117500 rows
# Processed 117600 rows
# Processed 117700 rows
# Processed 117800 rows
# Processed 117900 rows
# Processed 118000 rows
# Processed 118100 rows
# Processed 118200 rows
# Processed 118300 rows
# Processed 118400 rows
# Processed 118500 rows
# Processed 118600 rows
# Processed 118700 rows
# Processed 118800 rows
# Processed 118900 rows
# Processed 119000 rows
# Processed 119100 rows
# Processed 119200 rows
# Processed 119300 rows
# Processed 119400 rows
# Processed 119500 rows
# Processed 119600 rows
# Processed 119700 rows
# Processed 119800 rows
# Processed 119900 rows
# Processed 120000 rows
# Processed 120100 rows
# Processed 120200 rows
# Processed 120300 rows
# Processed 120400 rows
# Processed 120500 rows
# Processed 120600 rows
# Processed 120700 rows
# Processed 120800 rows
# Processed 120900 rows
# Processed 121000 rows
# Processed 121100 rows
# Processed 121200 rows
# Processed 121300 rows
# Processed 121400 rows
# Processed 121500 rows
# Processed 121600 rows
# Processed 121700 rows
# Processed 121800 rows
# Processed 121900 rows
# Processed 122000 rows
# Processed 122100 rows
# Processed 122200 rows
# Processed 122300 rows
# Processed 122400 rows
# Processed 122500 rows
# Processed 122600 rows
# Processed 122700 rows
# Processed 122800 rows
# Processed 122900 rows
# Processed 123000 rows
# Processed 123100 rows
# Processed 123200 rows
# Processed 123300 rows
# Processed 123400 rows
# Processed 123500 rows
# Processed 123600 rows
# Processed 123700 rows
# Processed 123800 rows
# Processed 123900 rows
# Processed 124000 rows
# Processed 124100 rows
# Processed 124200 rows
# Processed 124300 rows
# Processed 124400 rows
# Processed 124500 rows
# Processed 124600 rows
# Processed 124700 rows
# Processed 124800 rows
# Processed 124900 rows
# Processed 125000 rows
# Processed 125100 rows
# Processed 125200 rows
# Processed 125300 rows
# Processed 125400 rows
# Processed 125500 rows
# Processed 125600 rows
# Processed 125700 rows
# Processed 125800 rows
# Processed 125900 rows
# Processed 126000 rows
# Processed 126100 rows
# Processed 126200 rows
# Processed 126300 rows
# Processed 126400 rows
# Processed 126500 rows
# Processed 126600 rows
# Processed 126700 rows
# Processed 126800 rows
# Processed 126900 rows
# Processed 127000 rows
# Processed 127100 rows
# Processed 127200 rows
# Processed 127300 rows
# Processed 127400 rows
# Processed 127500 rows
# Processed 127600 rows
# Processed 127700 rows
# Processed 127800 rows
# Processed 127900 rows
# Processed 128000 rows
# Processed 128100 rows
# Processed 128200 rows
# Processed 128300 rows
# Processed 128400 rows
# Processed 128500 rows
# Processed 128600 rows
# Processed 128700 rows
# Processed 128800 rows
# Processed 128900 rows
# Processed 129000 rows
# Processed 129100 rows
# Processed 129200 rows
# Processed 129300 rows
# Processed 129400 rows
# Processed 129500 rows
# Processed 129600 rows
# Processed 129700 rows
# Processed 129800 rows
# Processed 129900 rows
# Processed 130000 rows
# Processed 130100 rows
# Processed 130200 rows
# Processed 130300 rows
# Processed 130400 rows
# Processed 130500 rows
# Processed 130600 rows
# Processed 130700 rows
# Processed 130800 rows
# Processed 130900 rows
# Processed 131000 rows
# Processed 131100 rows
# Processed 131200 rows
# Processed 131300 rows
# Processed 131400 rows
# Processed 131500 rows
# Processed 131600 rows
# Processed 131700 rows
# Processed 131800 rows
# Processed 131900 rows
# Processed 132000 rows
# Processed 132100 rows
# Processed 132200 rows
# Processed 132300 rows
# Processed 132400 rows
# Processed 132500 rows
# Processed 132600 rows
# Processed 132700 rows
# Processed 132800 rows
# Processed 132900 rows
# Processed 133000 rows
# Processed 133100 rows
# Processed 133200 rows
# Processed 133300 rows
# Processed 133400 rows
# Processed 133500 rows
# Processed 133600 rows
# Processed 133700 rows
# Processed 133800 rows
# Processed 133900 rows
# Processed 134000 rows
# Processed 134100 rows
# Processed 134200 rows
# Processed 134300 rows
# Processed 134400 rows
# Processed 134500 rows
# Processed 134600 rows
# Processed 134700 rows
# Processed 134800 rows
# Processed 134900 rows
# Processed 135000 rows
# Processed 135100 rows
# Processed 135200 rows
# Processed 135300 rows
# Processed 135400 rows
# Processed 135500 rows
# Processed 135600 rows
# Processed 135700 rows
# Processed 135800 rows
# Processed 135900 rows
# Processed 136000 rows
# Processed 136100 rows
# Processed 136200 rows
# Processed 136300 rows
# Processed 136400 rows
# Processed 136500 rows
# Processed 136600 rows
# Processed 136700 rows
# Processed 136800 rows
# Processed 136900 rows
# Processed 137000 rows
# Processed 137100 rows
# Processed 137200 rows
# Processed 137300 rows
# Processed 137400 rows
# Processed 137500 rows
# Processed 137600 rows
# Processed 137700 rows
# Processed 137800 rows
# Processed 137900 rows
# Processed 138000 rows
# Processed 138100 rows
# Processed 138200 rows
# Processed 138300 rows
# Processed 138400 rows
# Processed 138500 rows
# Processed 138600 rows
# Processed 138700 rows
# Processed 138800 rows
# Processed 138900 rows
# Processed 139000 rows
# Processed 139100 rows
# Processed 139200 rows
# Processed 139300 rows
# Processed 139400 rows
# Processed 139500 rows
# Processed 139600 rows
# Processed 139700 rows
# Processed 139800 rows
# Processed 139900 rows
# Processed 140000 rows
# Processed 140100 rows
# Processed 140200 rows
# Processed 140300 rows
# Processed 140400 rows
# Processed 140500 rows
# Processed 140600 rows
# Processed 140700 rows
# Processed 140800 rows
# Processed 140900 rows
# Processed 141000 rows
# Processed 141100 rows
# Processed 141200 rows
# Processed 141300 rows
# Processed 141400 rows
# Processed 141500 rows
# Processed 141600 rows
# Processed 141700 rows
# Processed 141800 rows
# Processed 141900 rows
# Processed 142000 rows
# Processed 142100 rows
# Processed 142200 rows
# Processed 142300 rows
# Processed 142400 rows
# Processed 142500 rows
# Processed 142600 rows
# Processed 142700 rows
# Processed 142800 rows
# Processed 142900 rows
# Processed 143000 rows
# Processed 143100 rows
# Processed 143200 rows
# Processed 143300 rows
# Processed 143400 rows
# Processed 143500 rows
# Processed 143600 rows
# Processed 143700 rows
# Processed 143800 rows
# Processed 143900 rows
# Processed 144000 rows
# Processed 144100 rows
# Processed 144200 rows
# Processed 144300 rows
# Processed 144400 rows
# Processed 144500 rows
# Processed 144600 rows
# Processed 144700 rows
# Processed 144800 rows
# Processed 144900 rows
# Processed 145000 rows
# Processed 145100 rows
# Processed 145200 rows
# Processed 145300 rows
# Processed 145400 rows
# Processed 145500 rows
# Processed 145600 rows
# Processed 145700 rows
# Processed 145800 rows
# Processed 145900 rows
# Processed 146000 rows
# Processed 146100 rows
# Processed 146200 rows
# Processed 146300 rows
# Processed 146400 rows
# Processed 146500 rows
# Processed 146600 rows
# Processed 146700 rows
# Processed 146800 rows
# Processed 146900 rows
# Processed 147000 rows
# Processed 147100 rows
# Processed 147200 rows
# Processed 147300 rows
# Processed 147400 rows
# Processed 147500 rows
# Processed 147600 rows
# Processed 147700 rows
# Processed 147800 rows
# Processed 147900 rows
# Processed 148000 rows
# Processed 148100 rows
# Processed 148200 rows
# Processed 148300 rows
# Processed 148400 rows
# Processed 148500 rows
# Processed 148600 rows
# Processed 148700 rows
# Processed 148800 rows
# Processed 148900 rows
# Processed 149000 rows
# Processed 149100 rows
# Processed 149200 rows
# Processed 149300 rows
# Processed 149400 rows
# Processed 149500 rows
# Processed 149600 rows
# Processed 149700 rows
# Processed 149800 rows
# Processed 149900 rows
# Processed 150000 rows
# Processed 150100 rows
# Processed 150200 rows
# Processed 150300 rows
# Processed 150400 rows
# Processed 150500 rows
# Processed 150600 rows
# Processed 150700 rows
# Processed 150800 rows
# Processed 150900 rows
# Processed 151000 rows
# Processed 151100 rows
# Processed 151200 rows
# Processed 151300 rows
# Processed 151400 rows
# Processed 151500 rows
# Processed 151600 rows
# Processed 151700 rows
# Processed 151800 rows
# Processed 151900 rows
# Processed 152000 rows
# Processed 152100 rows
# Processed 152200 rows
# Processed 152300 rows
# Processed 152400 rows
# Processed 152500 rows
# Processed 152600 rows
# Processed 152700 rows
# Processed 152800 rows
# Processed 152900 rows
# Processed 153000 rows
# Processed 153100 rows
# Processed 153200 rows
# Processed 153300 rows
# Processed 153400 rows
# Processed 153500 rows
# Processed 153600 rows
# Processed 153700 rows
# Processed 153800 rows
# Processed 153900 rows
# Processed 154000 rows
# Processed 154100 rows
# Processed 154200 rows
# Processed 154300 rows
# Processed 154400 rows
# Processed 154500 rows
# Processed 154600 rows
# Processed 154700 rows
# Processed 154800 rows
# Processed 154900 rows
# Processed 155000 rows
# Processed 155100 rows
# Processed 155200 rows
# Processed 155300 rows
# Processed 155400 rows
# Processed 155500 rows
# Processed 155600 rows
# Processed 155700 rows
# Processed 155800 rows
# Processed 155900 rows
# Processed 156000 rows
# Processed 156100 rows
# Processed 156200 rows
# Processed 156300 rows
# Processed 156400 rows
# Processed 156500 rows
# Processed 156600 rows
# Processed 156700 rows
# Processed 156800 rows
# Processed 156900 rows
# Processed 157000 rows
# Processed 157100 rows
# Processed 157200 rows
# Processed 157300 rows
# Processed 157400 rows
# Processed 157500 rows
# Processed 157600 rows
# Processed 157700 rows
# Processed 157800 rows
# Processed 157900 rows
# Processed 158000 rows
# Processed 158100 rows
# Processed 158200 rows
# Processed 158300 rows
# Processed 158400 rows
# Processed 158500 rows
# Processed 158600 rows
# Processed 158700 rows
# Processed 158800 rows
# Processed 158900 rows
# Processed 159000 rows
# Processed 159100 rows
# Processed 159200 rows
# Processed 159300 rows
# Processed 159400 rows
# Processed 159500 rows
# Processed 159600 rows
# Processed 159700 rows
# Processed 159800 rows
# Processed 159900 rows
# Processed 160000 rows
# Processed 160100 rows
# Processed 160200 rows
# Processed 160300 rows
# Processed 160400 rows
# Processed 160500 rows
# Processed 160600 rows
# Processed 160700 rows
# Processed 160800 rows
# Processed 160900 rows
# Processed 161000 rows
# Processed 161100 rows
# Processed 161200 rows
# Processed 161300 rows
# Processed 161400 rows
# Processed 161500 rows
# Processed 161600 rows
# Processed 161700 rows
# Processed 161800 rows
# Processed 161900 rows
# Processed 162000 rows
# Processed 162100 rows
# Processed 162200 rows
# Processed 162300 rows
# Processed 162400 rows
# Processed 162500 rows
# Processed 162600 rows
# Processed 162700 rows
# Processed 162800 rows
# Processed 162900 rows
# Processed 163000 rows
# Processed 163100 rows
# Processed 163200 rows
# Processed 163300 rows
# Processed 163400 rows
# Processed 163500 rows
# Processed 163600 rows
# Processed 163700 rows
# Processed 163800 rows
# Processed 163900 rows
# Processed 164000 rows
# Processed 164100 rows
# Processed 164200 rows
# Processed 164300 rows
# Processed 164400 rows
# Processed 164500 rows
# Processed 164600 rows
# Processed 164700 rows
# Processed 164800 rows
# Processed 164900 rows
# Processed 165000 rows
# Processed 165100 rows
# Processed 165200 rows
# Processed 165300 rows
# Processed 165400 rows
# Processed 165500 rows
# Processed 165600 rows
# Processed 165700 rows
# Processed 165800 rows
# Processed 165900 rows
# Processed 166000 rows
# Processed 166100 rows
# Processed 166200 rows
# Processed 166300 rows
# Processed 166400 rows
# Processed 166500 rows
# Processed 166600 rows
# Processed 166700 rows
# Processed 166800 rows
# Processed 166900 rows
# Processed 167000 rows
# Processed 167100 rows
# Processed 167200 rows
# Processed 167300 rows
# Processed 167400 rows
# Processed 167500 rows
# Processed 167600 rows
# Processed 167700 rows
# Processed 167800 rows
# Processed 167900 rows
# Processed 168000 rows
# Processed 168100 rows
# Processed 168200 rows
# Processed 168300 rows
# Processed 168400 rows
# Processed 168500 rows
# Processed 168600 rows
# Processed 168700 rows
# Processed 168800 rows
# Processed 168900 rows
# Processed 169000 rows
# Processed 169100 rows
# Processed 169200 rows
# Processed 169300 rows
# Processed 169400 rows
# Processed 169500 rows
# Processed 169600 rows
# Processed 169700 rows
# Processed 169800 rows
# Processed 169900 rows
# Processed 170000 rows
# Processed 170100 rows
# Processed 170200 rows
# Processed 170300 rows
# Processed 170400 rows
# Processed 170500 rows
# Processed 170600 rows
# Processed 170700 rows
# Processed 170800 rows
# Processed 170900 rows
# Processed 171000 rows
# Processed 171100 rows
# Processed 171200 rows
# Processed 171300 rows
# Processed 171400 rows
# Processed 171500 rows
# Processed 171600 rows
# Processed 171700 rows
# Processed 171800 rows
# Processed 171900 rows
# Processed 172000 rows
# Processed 172100 rows
# Processed 172200 rows
# Processed 172300 rows
# Processed 172400 rows
# Processed 172500 rows
# Processed 172600 rows
# Processed 172700 rows
# Processed 172800 rows
# Processed 172900 rows
# Processed 173000 rows
# Processed 173100 rows
# Processed 173200 rows
# Processed 173300 rows
# Processed 173400 rows
# Processed 173500 rows
# Processed 173600 rows
# Processed 173700 rows
# Processed 173800 rows
# Processed 173900 rows
# Processed 174000 rows
# Processed 174100 rows
# Processed 174200 rows
# Processed 174300 rows
# Processed 174400 rows
# Processed 174500 rows
# Processed 174600 rows
# Processed 174700 rows
# Processed 174800 rows
# Processed 174900 rows
# Processed 175000 rows
# Processed 175100 rows
# Processed 175200 rows
# Processed 175300 rows
# Processed 175400 rows
# Processed 175500 rows
# Processed 175600 rows
# Processed 175700 rows
# Processed 175800 rows
# Processed 175900 rows
# Processed 176000 rows
# Processed 176100 rows
# Processed 176200 rows
# Processed 176300 rows
# Processed 176400 rows
# Processed 176500 rows
# Processed 176600 rows
# Processed 176700 rows
# Processed 176800 rows
# Processed 176900 rows
# Processed 177000 rows
# Processed 177100 rows
# Processed 177200 rows
# Processed 177300 rows
# Processed 177400 rows
# Processed 177500 rows
# Processed 177600 rows
# Processed 177700 rows
# Processed 177800 rows
# Processed 177900 rows
# Processed 178000 rows
# Processed 178100 rows
# Processed 178200 rows
# Processed 178300 rows
# Processed 178400 rows
# Processed 178500 rows
# Processed 178600 rows
# Processed 178700 rows
# Processed 178800 rows
# Processed 178900 rows
# Processed 179000 rows
# Processed 179100 rows
# Processed 179200 rows
# Processed 179300 rows
# Processed 179400 rows
# Processed 179500 rows
# Processed 179600 rows
# Processed 179700 rows
# Processed 179800 rows
# Processed 179900 rows
# Processed 180000 rows
# Processed 180100 rows
# Processed 180200 rows
# Processed 180300 rows
# Processed 180400 rows
# Processed 180500 rows
# Processed 180600 rows
# Processed 180700 rows
# Processed 180800 rows
# Processed 180900 rows
# Processed 181000 rows
# Processed 181100 rows
# Processed 181200 rows
# Processed 181300 rows
# Processed 181400 rows
# Processed 181500 rows
# Processed 181600 rows
# Processed 181700 rows
# Processed 181800 rows
# Processed 181900 rows
# Processed 182000 rows
# Processed 182100 rows
# Processed 182200 rows
# Processed 182300 rows
# Processed 182400 rows
# Processed 182500 rows
# Processed 182600 rows
# Processed 182700 rows
# Processed 182800 rows
# Processed 182900 rows
# Processed 183000 rows
# Processed 183100 rows
# Processed 183200 rows
# Processed 183300 rows
# Processed 183400 rows
# Processed 183500 rows
# Processed 183600 rows
# Processed 183700 rows
# Processed 183800 rows
# Processed 183900 rows
# Processed 184000 rows
# Processed 184100 rows
# Processed 184200 rows
# Processed 184300 rows
# Processed 184400 rows
# Processed 184500 rows
# Processed 184600 rows
# Processed 184700 rows
# Processed 184800 rows
# Processed 184900 rows
# Processed 185000 rows
# Processed 185100 rows
# Processed 185200 rows
# Processed 185300 rows
# Processed 185400 rows
# Processed 185500 rows
# Processed 185600 rows
# Processed 185700 rows
# Processed 185800 rows
# Processed 185900 rows
# Processed 186000 rows
# Processed 186100 rows
# Processed 186200 rows
# Processed 186300 rows
# Processed 186400 rows
# Processed 186500 rows
# Processed 186600 rows
# Processed 186700 rows
# Processed 186800 rows
# Processed 186900 rows
# Processed 187000 rows
# Processed 187100 rows
# Processed 187200 rows
# Processed 187300 rows
# Processed 187400 rows
# Processed 187500 rows
# Processed 187600 rows
# Processed 187700 rows
# Processed 187800 rows
# Processed 187900 rows
# Processed 188000 rows
# Processed 188100 rows
# Processed 188200 rows
# Processed 188300 rows
# Processed 188400 rows
# Processed 188500 rows
# Processed 188600 rows
# Processed 188700 rows
# Processed 188800 rows
# Processed 188900 rows
# Processed 189000 rows
# Processed 189100 rows
# Processed 189200 rows
# Processed 189300 rows
# Processed 189400 rows
# Processed 189500 rows
# Processed 189600 rows
# Processed 189700 rows
# Processed 189800 rows
# Processed 189900 rows
# Processed 190000 rows
# Processed 190100 rows
# Processed 190200 rows
# Processed 190300 rows
# Processed 190400 rows
# Processed 190500 rows
# Processed 190600 rows
# Processed 190700 rows
# Processed 190800 rows
# Processed 190900 rows
# Processed 191000 rows
# Processed 191100 rows
# Processed 191200 rows
# Processed 191300 rows
# Processed 191400 rows
# Processed 191500 rows
# Processed 191600 rows
# Processed 191700 rows
# Processed 191800 rows
# Processed 191900 rows
# Processed 192000 rows
# Processed 192100 rows
# Processed 192200 rows
# Processed 192300 rows
# Processed 192400 rows
# Processed 192500 rows
# Processed 192600 rows
# Processed 192700 rows
# Processed 192800 rows
# Processed 192900 rows
# Processed 193000 rows
# Processed 193100 rows
# Processed 193200 rows
# Processed 193300 rows
# Processed 193400 rows
# Processed 193500 rows
# Processed 193600 rows
# Processed 193700 rows
# Processed 193800 rows
# Processed 193900 rows
# Processed 194000 rows
# Processed 194100 rows
# Processed 194200 rows
# Processed 194300 rows
# Processed 194400 rows
# Processed 194500 rows
# Processed 194600 rows
# Processed 194700 rows
# Processed 194800 rows
# Processed 194900 rows
# Processed 195000 rows
# Processed 195100 rows
# Processed 195200 rows
# Processed 195300 rows
# Processed 195400 rows
# Processed 195500 rows
# Processed 195600 rows
# Processed 195700 rows
# Processed 195800 rows
# Processed 195900 rows
# Processed 196000 rows
# Processed 196100 rows
# Processed 196200 rows
# Processed 196300 rows
# Processed 196400 rows
# Processed 196500 rows
# Processed 196600 rows
# Processed 196700 rows
# Processed 196800 rows
# Processed 196900 rows
# Processed 197000 rows
# Processed 197100 rows
# Processed 197200 rows
# Processed 197300 rows
# Processed 197400 rows
# Processed 197500 rows
# Processed 197600 rows
# Processed 197700 rows
# Processed 197800 rows
# Processed 197900 rows
# Processed 198000 rows
# Processed 198100 rows
# Processed 198200 rows
# Processed 198300 rows
# Processed 198400 rows
# Processed 198500 rows
# Processed 198600 rows
# Processed 198700 rows
# Processed 198800 rows
# Processed 198900 rows
# Processed 199000 rows
# Processed 199100 rows
# Processed 199200 rows
# Processed 199300 rows
# Processed 199400 rows
# Processed 199500 rows
# Processed 199600 rows
# Processed 199700 rows
# Processed 199800 rows
# Processed 199900 rows
# Processed 200000 rows
# Dataset shape: (162992, 256)
# Dataset shape: (37008, 256)

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

file_path = r"R_RPM_raw.npy"
data = np.load(file_path)

output_folder = r"R_RPM_histograms"
os.makedirs(output_folder, exist_ok=True)

rows_per_image = 256
num_rows = data.shape[0]

for start_idx in range(0, num_rows, rows_per_image):
    end_idx = min(start_idx + rows_per_image, num_rows)
    combined_data = data[start_idx:end_idx]

    print(f"Creating 2D histogram image for rows {start_idx} to {end_idx - 1}")
    
    combined_data_normalized = combined_data.astype(np.float32)
    combined_data_max = combined_data_normalized.max(axis=0)
    combined_data_max[combined_data_max == 0] = 1
    combined_data_normalized /= combined_data_max

    combined_data_normalized *= 255
    combined_data_normalized = combined_data_normalized.astype(np.uint8)

    plt.figure(figsize=(25, 25))
    plt.imshow(combined_data_normalized, cmap='binary', aspect='auto', interpolation='nearest')

    output_file = os.path.join(output_folder, f"2d_histogram_{start_idx}_{end_idx - 1}.png")
    plt.savefig(output_file, bbox_inches='tight', pad_inches=0)
    plt.close()
# Out:
# Creating 2D histogram image for rows 0 to 255
# Creating 2D histogram image for rows 256 to 511
# Creating 2D histogram image for rows 512 to 767
# Creating 2D histogram image for rows 768 to 1023
# Creating 2D histogram image for rows 1024 to 1279
# Creating 2D histogram image for rows 1280 to 1535
# Creating 2D histogram image for rows 1536 to 1791
# Creating 2D histogram image for rows 1792 to 2047
# Creating 2D histogram image for rows 2048 to 2303
# Creating 2D histogram image for rows 2304 to 2559
# Creating 2D histogram image for rows 2560 to 2815
# Creating 2D histogram image for rows 2816 to 3071
# Creating 2D histogram image for rows 3072 to 3327
# Creating 2D histogram image for rows 3328 to 3583
# Creating 2D histogram image for rows 3584 to 3839
# Creating 2D histogram image for rows 3840 to 4095
# Creating 2D histogram image for rows 4096 to 4351
# Creating 2D histogram image for rows 4352 to 4607
# Creating 2D histogram image for rows 4608 to 4863
# Creating 2D histogram image for rows 4864 to 5119
# Creating 2D histogram image for rows 5120 to 5375
# Creating 2D histogram image for rows 5376 to 5631
# Creating 2D histogram image for rows 5632 to 5887
# Creating 2D histogram image for rows 5888 to 6143
# Creating 2D histogram image for rows 6144 to 6399
# Creating 2D histogram image for rows 6400 to 6655
# Creating 2D histogram image for rows 6656 to 6911
# Creating 2D histogram image for rows 6912 to 7167
# Creating 2D histogram image for rows 7168 to 7423
# Creating 2D histogram image for rows 7424 to 7679
# Creating 2D histogram image for rows 7680 to 7935
# Creating 2D histogram image for rows 7936 to 8191
# Creating 2D histogram image for rows 8192 to 8447
# Creating 2D histogram image for rows 8448 to 8703
# Creating 2D histogram image for rows 8704 to 8959
# Creating 2D histogram image for rows 8960 to 9215
# Creating 2D histogram image for rows 9216 to 9471
# Creating 2D histogram image for rows 9472 to 9727
# Creating 2D histogram image for rows 9728 to 9983
# Creating 2D histogram image for rows 9984 to 10239
# Creating 2D histogram image for rows 10240 to 10495
# Creating 2D histogram image for rows 10496 to 10751
# Creating 2D histogram image for rows 10752 to 11007
# Creating 2D histogram image for rows 11008 to 11263
# Creating 2D histogram image for rows 11264 to 11519
# Creating 2D histogram image for rows 11520 to 11775
# Creating 2D histogram image for rows 11776 to 12031
# Creating 2D histogram image for rows 12032 to 12287
# Creating 2D histogram image for rows 12288 to 12543
# Creating 2D histogram image for rows 12544 to 12799
# Creating 2D histogram image for rows 12800 to 13055
# Creating 2D histogram image for rows 13056 to 13311
# Creating 2D histogram image for rows 13312 to 13567
# Creating 2D histogram image for rows 13568 to 13823
# Creating 2D histogram image for rows 13824 to 14079
# Creating 2D histogram image for rows 14080 to 14335
# Creating 2D histogram image for rows 14336 to 14591
# Creating 2D histogram image for rows 14592 to 14847
# Creating 2D histogram image for rows 14848 to 15103
# Creating 2D histogram image for rows 15104 to 15359
# Creating 2D histogram image for rows 15360 to 15615
# Creating 2D histogram image for rows 15616 to 15871
# Creating 2D histogram image for rows 15872 to 16127
# Creating 2D histogram image for rows 16128 to 16383
# Creating 2D histogram image for rows 16384 to 16639
# Creating 2D histogram image for rows 16640 to 16895
# Creating 2D histogram image for rows 16896 to 17151
# Creating 2D histogram image for rows 17152 to 17407
# Creating 2D histogram image for rows 17408 to 17663
# Creating 2D histogram image for rows 17664 to 17919
# Creating 2D histogram image for rows 17920 to 18175
# Creating 2D histogram image for rows 18176 to 18431
# Creating 2D histogram image for rows 18432 to 18687
# Creating 2D histogram image for rows 18688 to 18943
# Creating 2D histogram image for rows 18944 to 19199
# Creating 2D histogram image for rows 19200 to 19455
# Creating 2D histogram image for rows 19456 to 19711
# Creating 2D histogram image for rows 19712 to 19967
# Creating 2D histogram image for rows 19968 to 20223
# Creating 2D histogram image for rows 20224 to 20479
# Creating 2D histogram image for rows 20480 to 20735
# Creating 2D histogram image for rows 20736 to 20991
# Creating 2D histogram image for rows 20992 to 21247
# Creating 2D histogram image for rows 21248 to 21503
# Creating 2D histogram image for rows 21504 to 21759
# Creating 2D histogram image for rows 21760 to 22015
# Creating 2D histogram image for rows 22016 to 22271
# Creating 2D histogram image for rows 22272 to 22527
# Creating 2D histogram image for rows 22528 to 22783
# Creating 2D histogram image for rows 22784 to 23039
# Creating 2D histogram image for rows 23040 to 23295
# Creating 2D histogram image for rows 23296 to 23551
# Creating 2D histogram image for rows 23552 to 23807
# Creating 2D histogram image for rows 23808 to 24063
# Creating 2D histogram image for rows 24064 to 24319
# Creating 2D histogram image for rows 24320 to 24575
# Creating 2D histogram image for rows 24576 to 24831
# Creating 2D histogram image for rows 24832 to 25087
# Creating 2D histogram image for rows 25088 to 25343
# Creating 2D histogram image for rows 25344 to 25599
# Creating 2D histogram image for rows 25600 to 25855
# Creating 2D histogram image for rows 25856 to 26111
# Creating 2D histogram image for rows 26112 to 26367
# Creating 2D histogram image for rows 26368 to 26623
# Creating 2D histogram image for rows 26624 to 26879
# Creating 2D histogram image for rows 26880 to 27135
# Creating 2D histogram image for rows 27136 to 27391
# Creating 2D histogram image for rows 27392 to 27647
# Creating 2D histogram image for rows 27648 to 27903
# Creating 2D histogram image for rows 27904 to 28159
# Creating 2D histogram image for rows 28160 to 28415
# Creating 2D histogram image for rows 28416 to 28671
# Creating 2D histogram image for rows 28672 to 28927
# Creating 2D histogram image for rows 28928 to 29183
# Creating 2D histogram image for rows 29184 to 29439
# Creating 2D histogram image for rows 29440 to 29695
# Creating 2D histogram image for rows 29696 to 29951
# Creating 2D histogram image for rows 29952 to 30207
# Creating 2D histogram image for rows 30208 to 30463
# Creating 2D histogram image for rows 30464 to 30719
# Creating 2D histogram image for rows 30720 to 30975
# Creating 2D histogram image for rows 30976 to 31231
# Creating 2D histogram image for rows 31232 to 31487
# Creating 2D histogram image for rows 31488 to 31743
# Creating 2D histogram image for rows 31744 to 31999
# Creating 2D histogram image for rows 32000 to 32255
# Creating 2D histogram image for rows 32256 to 32511
# Creating 2D histogram image for rows 32512 to 32767
# Creating 2D histogram image for rows 32768 to 33023
# Creating 2D histogram image for rows 33024 to 33279
# Creating 2D histogram image for rows 33280 to 33535
# Creating 2D histogram image for rows 33536 to 33791
# Creating 2D histogram image for rows 33792 to 34047
# Creating 2D histogram image for rows 34048 to 34303
# Creating 2D histogram image for rows 34304 to 34559
# Creating 2D histogram image for rows 34560 to 34815
# Creating 2D histogram image for rows 34816 to 35071
# Creating 2D histogram image for rows 35072 to 35327
# Creating 2D histogram image for rows 35328 to 35583
# Creating 2D histogram image for rows 35584 to 35839
# Creating 2D histogram image for rows 35840 to 36095
# Creating 2D histogram image for rows 36096 to 36351
# Creating 2D histogram image for rows 36352 to 36607
# Creating 2D histogram image for rows 36608 to 36863
# Creating 2D histogram image for rows 36864 to 37119
# Creating 2D histogram image for rows 37120 to 37375
# Creating 2D histogram image for rows 37376 to 37631
# Creating 2D histogram image for rows 37632 to 37887
# Creating 2D histogram image for rows 37888 to 38143
# Creating 2D histogram image for rows 38144 to 38399
# Creating 2D histogram image for rows 38400 to 38655
# Creating 2D histogram image for rows 38656 to 38911
# Creating 2D histogram image for rows 38912 to 39167
# Creating 2D histogram image for rows 39168 to 39423
# Creating 2D histogram image for rows 39424 to 39679
# Creating 2D histogram image for rows 39680 to 39935
# Creating 2D histogram image for rows 39936 to 40191
# Creating 2D histogram image for rows 40192 to 40447
# Creating 2D histogram image for rows 40448 to 40703
# Creating 2D histogram image for rows 40704 to 40959
# Creating 2D histogram image for rows 40960 to 41215
# Creating 2D histogram image for rows 41216 to 41471
# Creating 2D histogram image for rows 41472 to 41727
# Creating 2D histogram image for rows 41728 to 41983
# Creating 2D histogram image for rows 41984 to 42239
# Creating 2D histogram image for rows 42240 to 42495
# Creating 2D histogram image for rows 42496 to 42751
# Creating 2D histogram image for rows 42752 to 43007
# Creating 2D histogram image for rows 43008 to 43263
# Creating 2D histogram image for rows 43264 to 43519
# Creating 2D histogram image for rows 43520 to 43775
# Creating 2D histogram image for rows 43776 to 44031
# Creating 2D histogram image for rows 44032 to 44287
# Creating 2D histogram image for rows 44288 to 44543
# Creating 2D histogram image for rows 44544 to 44799
# Creating 2D histogram image for rows 44800 to 45055
# Creating 2D histogram image for rows 45056 to 45311
# Creating 2D histogram image for rows 45312 to 45567
# Creating 2D histogram image for rows 45568 to 45823
# Creating 2D histogram image for rows 45824 to 46079
# Creating 2D histogram image for rows 46080 to 46335
# Creating 2D histogram image for rows 46336 to 46591
# Creating 2D histogram image for rows 46592 to 46847
# Creating 2D histogram image for rows 46848 to 47103
# Creating 2D histogram image for rows 47104 to 47359
# Creating 2D histogram image for rows 47360 to 47615
# Creating 2D histogram image for rows 47616 to 47871
# Creating 2D histogram image for rows 47872 to 48127
# Creating 2D histogram image for rows 48128 to 48383
# Creating 2D histogram image for rows 48384 to 48639
# Creating 2D histogram image for rows 48640 to 48895
# Creating 2D histogram image for rows 48896 to 49151
# Creating 2D histogram image for rows 49152 to 49407
# Creating 2D histogram image for rows 49408 to 49663
# Creating 2D histogram image for rows 49664 to 49919
# Creating 2D histogram image for rows 49920 to 50175
# Creating 2D histogram image for rows 50176 to 50431
# Creating 2D histogram image for rows 50432 to 50687
# Creating 2D histogram image for rows 50688 to 50943
# Creating 2D histogram image for rows 50944 to 51199
# Creating 2D histogram image for rows 51200 to 51455
# Creating 2D histogram image for rows 51456 to 51711
# Creating 2D histogram image for rows 51712 to 51967
# Creating 2D histogram image for rows 51968 to 52223
# Creating 2D histogram image for rows 52224 to 52479
# Creating 2D histogram image for rows 52480 to 52735
# Creating 2D histogram image for rows 52736 to 52991
# Creating 2D histogram image for rows 52992 to 53247
# Creating 2D histogram image for rows 53248 to 53503
# Creating 2D histogram image for rows 53504 to 53759
# Creating 2D histogram image for rows 53760 to 54015
# Creating 2D histogram image for rows 54016 to 54271
# Creating 2D histogram image for rows 54272 to 54527
# Creating 2D histogram image for rows 54528 to 54783
# Creating 2D histogram image for rows 54784 to 55039
# Creating 2D histogram image for rows 55040 to 55295
# Creating 2D histogram image for rows 55296 to 55551
# Creating 2D histogram image for rows 55552 to 55807
# Creating 2D histogram image for rows 55808 to 56063
# Creating 2D histogram image for rows 56064 to 56319
# Creating 2D histogram image for rows 56320 to 56575
# Creating 2D histogram image for rows 56576 to 56831
# Creating 2D histogram image for rows 56832 to 57087
# Creating 2D histogram image for rows 57088 to 57343
# Creating 2D histogram image for rows 57344 to 57599
# Creating 2D histogram image for rows 57600 to 57855
# Creating 2D histogram image for rows 57856 to 58111
# Creating 2D histogram image for rows 58112 to 58367
# Creating 2D histogram image for rows 58368 to 58623
# Creating 2D histogram image for rows 58624 to 58879
# Creating 2D histogram image for rows 58880 to 59135
# Creating 2D histogram image for rows 59136 to 59391
# Creating 2D histogram image for rows 59392 to 59647
# Creating 2D histogram image for rows 59648 to 59903
# Creating 2D histogram image for rows 59904 to 60159
# Creating 2D histogram image for rows 60160 to 60415
# Creating 2D histogram image for rows 60416 to 60671
# Creating 2D histogram image for rows 60672 to 60927
# Creating 2D histogram image for rows 60928 to 61183
# Creating 2D histogram image for rows 61184 to 61439
# Creating 2D histogram image for rows 61440 to 61695
# Creating 2D histogram image for rows 61696 to 61951
# Creating 2D histogram image for rows 61952 to 62207
# Creating 2D histogram image for rows 62208 to 62463
# Creating 2D histogram image for rows 62464 to 62719
# Creating 2D histogram image for rows 62720 to 62975
# Creating 2D histogram image for rows 62976 to 63231
# Creating 2D histogram image for rows 63232 to 63487
# Creating 2D histogram image for rows 63488 to 63743
# Creating 2D histogram image for rows 63744 to 63999
# Creating 2D histogram image for rows 64000 to 64255
# Creating 2D histogram image for rows 64256 to 64511
# Creating 2D histogram image for rows 64512 to 64767
# Creating 2D histogram image for rows 64768 to 65023
# Creating 2D histogram image for rows 65024 to 65279
# Creating 2D histogram image for rows 65280 to 65535
# Creating 2D histogram image for rows 65536 to 65791
# Creating 2D histogram image for rows 65792 to 66047
# Creating 2D histogram image for rows 66048 to 66303
# Creating 2D histogram image for rows 66304 to 66559
# Creating 2D histogram image for rows 66560 to 66815
# Creating 2D histogram image for rows 66816 to 67071
# Creating 2D histogram image for rows 67072 to 67327
# Creating 2D histogram image for rows 67328 to 67583
# Creating 2D histogram image for rows 67584 to 67839
# Creating 2D histogram image for rows 67840 to 68095
# Creating 2D histogram image for rows 68096 to 68351
# Creating 2D histogram image for rows 68352 to 68607
# Creating 2D histogram image for rows 68608 to 68863
# Creating 2D histogram image for rows 68864 to 69119
# Creating 2D histogram image for rows 69120 to 69375
# Creating 2D histogram image for rows 69376 to 69631
# Creating 2D histogram image for rows 69632 to 69887
# Creating 2D histogram image for rows 69888 to 70143
# Creating 2D histogram image for rows 70144 to 70399
# Creating 2D histogram image for rows 70400 to 70655
# Creating 2D histogram image for rows 70656 to 70911
# Creating 2D histogram image for rows 70912 to 71167
# Creating 2D histogram image for rows 71168 to 71423
# Creating 2D histogram image for rows 71424 to 71679
# Creating 2D histogram image for rows 71680 to 71935
# Creating 2D histogram image for rows 71936 to 72191
# Creating 2D histogram image for rows 72192 to 72447
# Creating 2D histogram image for rows 72448 to 72703
# Creating 2D histogram image for rows 72704 to 72959
# Creating 2D histogram image for rows 72960 to 73215
# Creating 2D histogram image for rows 73216 to 73471
# Creating 2D histogram image for rows 73472 to 73727
# Creating 2D histogram image for rows 73728 to 73983
# Creating 2D histogram image for rows 73984 to 74239
# Creating 2D histogram image for rows 74240 to 74495
# Creating 2D histogram image for rows 74496 to 74751
# Creating 2D histogram image for rows 74752 to 75007
# Creating 2D histogram image for rows 75008 to 75263
# Creating 2D histogram image for rows 75264 to 75519
# Creating 2D histogram image for rows 75520 to 75775
# Creating 2D histogram image for rows 75776 to 76031
# Creating 2D histogram image for rows 76032 to 76287
# Creating 2D histogram image for rows 76288 to 76543
# Creating 2D histogram image for rows 76544 to 76799
# Creating 2D histogram image for rows 76800 to 77055
# Creating 2D histogram image for rows 77056 to 77311
# Creating 2D histogram image for rows 77312 to 77567
# Creating 2D histogram image for rows 77568 to 77823
# Creating 2D histogram image for rows 77824 to 78079
# Creating 2D histogram image for rows 78080 to 78335
# Creating 2D histogram image for rows 78336 to 78591
# Creating 2D histogram image for rows 78592 to 78847
# Creating 2D histogram image for rows 78848 to 79103
# Creating 2D histogram image for rows 79104 to 79359
# Creating 2D histogram image for rows 79360 to 79615
# Creating 2D histogram image for rows 79616 to 79871
# Creating 2D histogram image for rows 79872 to 80127
# Creating 2D histogram image for rows 80128 to 80383
# Creating 2D histogram image for rows 80384 to 80639
# Creating 2D histogram image for rows 80640 to 80895
# Creating 2D histogram image for rows 80896 to 81151
# Creating 2D histogram image for rows 81152 to 81407
# Creating 2D histogram image for rows 81408 to 81663
# Creating 2D histogram image for rows 81664 to 81919
# Creating 2D histogram image for rows 81920 to 82175
# Creating 2D histogram image for rows 82176 to 82431
# Creating 2D histogram image for rows 82432 to 82687
# Creating 2D histogram image for rows 82688 to 82943
# Creating 2D histogram image for rows 82944 to 83199
# Creating 2D histogram image for rows 83200 to 83455
# Creating 2D histogram image for rows 83456 to 83711
# Creating 2D histogram image for rows 83712 to 83967
# Creating 2D histogram image for rows 83968 to 84223
# Creating 2D histogram image for rows 84224 to 84479
# Creating 2D histogram image for rows 84480 to 84735
# Creating 2D histogram image for rows 84736 to 84991
# Creating 2D histogram image for rows 84992 to 85247
# Creating 2D histogram image for rows 85248 to 85503
# Creating 2D histogram image for rows 85504 to 85759
# Creating 2D histogram image for rows 85760 to 86015
# Creating 2D histogram image for rows 86016 to 86271
# Creating 2D histogram image for rows 86272 to 86527
# Creating 2D histogram image for rows 86528 to 86783
# Creating 2D histogram image for rows 86784 to 87039
# Creating 2D histogram image for rows 87040 to 87295
# Creating 2D histogram image for rows 87296 to 87551
# Creating 2D histogram image for rows 87552 to 87807
# Creating 2D histogram image for rows 87808 to 88063
# Creating 2D histogram image for rows 88064 to 88319
# Creating 2D histogram image for rows 88320 to 88575
# Creating 2D histogram image for rows 88576 to 88831
# Creating 2D histogram image for rows 88832 to 89087
# Creating 2D histogram image for rows 89088 to 89343
# Creating 2D histogram image for rows 89344 to 89599
# Creating 2D histogram image for rows 89600 to 89855
# Creating 2D histogram image for rows 89856 to 90111
# Creating 2D histogram image for rows 90112 to 90367
# Creating 2D histogram image for rows 90368 to 90623
# Creating 2D histogram image for rows 90624 to 90879
# Creating 2D histogram image for rows 90880 to 91135
# Creating 2D histogram image for rows 91136 to 91391
# Creating 2D histogram image for rows 91392 to 91647
# Creating 2D histogram image for rows 91648 to 91903
# Creating 2D histogram image for rows 91904 to 92159
# Creating 2D histogram image for rows 92160 to 92415
# Creating 2D histogram image for rows 92416 to 92671
# Creating 2D histogram image for rows 92672 to 92927
# Creating 2D histogram image for rows 92928 to 93183
# Creating 2D histogram image for rows 93184 to 93439
# Creating 2D histogram image for rows 93440 to 93695
# Creating 2D histogram image for rows 93696 to 93951
# Creating 2D histogram image for rows 93952 to 94207
# Creating 2D histogram image for rows 94208 to 94463
# Creating 2D histogram image for rows 94464 to 94719
# Creating 2D histogram image for rows 94720 to 94975
# Creating 2D histogram image for rows 94976 to 95231
# Creating 2D histogram image for rows 95232 to 95487
# Creating 2D histogram image for rows 95488 to 95743
# Creating 2D histogram image for rows 95744 to 95999
# Creating 2D histogram image for rows 96000 to 96255
# Creating 2D histogram image for rows 96256 to 96511
# Creating 2D histogram image for rows 96512 to 96767
# Creating 2D histogram image for rows 96768 to 97023
# Creating 2D histogram image for rows 97024 to 97279
# Creating 2D histogram image for rows 97280 to 97535
# Creating 2D histogram image for rows 97536 to 97791
# Creating 2D histogram image for rows 97792 to 98047
# Creating 2D histogram image for rows 98048 to 98303
# Creating 2D histogram image for rows 98304 to 98559
# Creating 2D histogram image for rows 98560 to 98815
# Creating 2D histogram image for rows 98816 to 99071
# Creating 2D histogram image for rows 99072 to 99327
# Creating 2D histogram image for rows 99328 to 99583
# Creating 2D histogram image for rows 99584 to 99839
# Creating 2D histogram image for rows 99840 to 100095
# Creating 2D histogram image for rows 100096 to 100351
# Creating 2D histogram image for rows 100352 to 100607
# Creating 2D histogram image for rows 100608 to 100863
# Creating 2D histogram image for rows 100864 to 101119
# Creating 2D histogram image for rows 101120 to 101375
# Creating 2D histogram image for rows 101376 to 101631
# Creating 2D histogram image for rows 101632 to 101887
# Creating 2D histogram image for rows 101888 to 102143
# Creating 2D histogram image for rows 102144 to 102399
# Creating 2D histogram image for rows 102400 to 102655
# Creating 2D histogram image for rows 102656 to 102911
# Creating 2D histogram image for rows 102912 to 103167
# Creating 2D histogram image for rows 103168 to 103423
# Creating 2D histogram image for rows 103424 to 103679
# Creating 2D histogram image for rows 103680 to 103935
# Creating 2D histogram image for rows 103936 to 104191
# Creating 2D histogram image for rows 104192 to 104447
# Creating 2D histogram image for rows 104448 to 104703
# Creating 2D histogram image for rows 104704 to 104959
# Creating 2D histogram image for rows 104960 to 105215
# Creating 2D histogram image for rows 105216 to 105471
# Creating 2D histogram image for rows 105472 to 105727
# Creating 2D histogram image for rows 105728 to 105983
# Creating 2D histogram image for rows 105984 to 106239
# Creating 2D histogram image for rows 106240 to 106495
# Creating 2D histogram image for rows 106496 to 106751
# Creating 2D histogram image for rows 106752 to 107007
# Creating 2D histogram image for rows 107008 to 107263
# Creating 2D histogram image for rows 107264 to 107519
# Creating 2D histogram image for rows 107520 to 107775
# Creating 2D histogram image for rows 107776 to 108031
# Creating 2D histogram image for rows 108032 to 108287
# Creating 2D histogram image for rows 108288 to 108543
# Creating 2D histogram image for rows 108544 to 108799
# Creating 2D histogram image for rows 108800 to 109055
# Creating 2D histogram image for rows 109056 to 109311
# Creating 2D histogram image for rows 109312 to 109567
# Creating 2D histogram image for rows 109568 to 109823
# Creating 2D histogram image for rows 109824 to 110079
# Creating 2D histogram image for rows 110080 to 110335
# Creating 2D histogram image for rows 110336 to 110591
# Creating 2D histogram image for rows 110592 to 110847
# Creating 2D histogram image for rows 110848 to 111103
# Creating 2D histogram image for rows 111104 to 111359
# Creating 2D histogram image for rows 111360 to 111615
# Creating 2D histogram image for rows 111616 to 111871
# Creating 2D histogram image for rows 111872 to 112127
# Creating 2D histogram image for rows 112128 to 112383
# Creating 2D histogram image for rows 112384 to 112639
# Creating 2D histogram image for rows 112640 to 112895
# Creating 2D histogram image for rows 112896 to 113151
# Creating 2D histogram image for rows 113152 to 113407
# Creating 2D histogram image for rows 113408 to 113663
# Creating 2D histogram image for rows 113664 to 113919
# Creating 2D histogram image for rows 113920 to 114175
# Creating 2D histogram image for rows 114176 to 114431
# Creating 2D histogram image for rows 114432 to 114687
# Creating 2D histogram image for rows 114688 to 114943
# Creating 2D histogram image for rows 114944 to 115199
# Creating 2D histogram image for rows 115200 to 115455
# Creating 2D histogram image for rows 115456 to 115711
# Creating 2D histogram image for rows 115712 to 115967
# Creating 2D histogram image for rows 115968 to 116223
# Creating 2D histogram image for rows 116224 to 116479
# Creating 2D histogram image for rows 116480 to 116735
# Creating 2D histogram image for rows 116736 to 116991
# Creating 2D histogram image for rows 116992 to 117247
# Creating 2D histogram image for rows 117248 to 117503
# Creating 2D histogram image for rows 117504 to 117759
# Creating 2D histogram image for rows 117760 to 118015
# Creating 2D histogram image for rows 118016 to 118271
# Creating 2D histogram image for rows 118272 to 118527
# Creating 2D histogram image for rows 118528 to 118783
# Creating 2D histogram image for rows 118784 to 119039
# Creating 2D histogram image for rows 119040 to 119295
# Creating 2D histogram image for rows 119296 to 119551
# Creating 2D histogram image for rows 119552 to 119807
# Creating 2D histogram image for rows 119808 to 120063
# Creating 2D histogram image for rows 120064 to 120319
# Creating 2D histogram image for rows 120320 to 120575
# Creating 2D histogram image for rows 120576 to 120831
# Creating 2D histogram image for rows 120832 to 121087
# Creating 2D histogram image for rows 121088 to 121343
# Creating 2D histogram image for rows 121344 to 121599
# Creating 2D histogram image for rows 121600 to 121855
# Creating 2D histogram image for rows 121856 to 122111
# Creating 2D histogram image for rows 122112 to 122367
# Creating 2D histogram image for rows 122368 to 122623
# Creating 2D histogram image for rows 122624 to 122879
# Creating 2D histogram image for rows 122880 to 123135
# Creating 2D histogram image for rows 123136 to 123391
# Creating 2D histogram image for rows 123392 to 123647
# Creating 2D histogram image for rows 123648 to 123903
# Creating 2D histogram image for rows 123904 to 124159
# Creating 2D histogram image for rows 124160 to 124415
# Creating 2D histogram image for rows 124416 to 124671
# Creating 2D histogram image for rows 124672 to 124927
# Creating 2D histogram image for rows 124928 to 125183
# Creating 2D histogram image for rows 125184 to 125439
# Creating 2D histogram image for rows 125440 to 125695
# Creating 2D histogram image for rows 125696 to 125951
# Creating 2D histogram image for rows 125952 to 126207
# Creating 2D histogram image for rows 126208 to 126463
# Creating 2D histogram image for rows 126464 to 126719
# Creating 2D histogram image for rows 126720 to 126975
# Creating 2D histogram image for rows 126976 to 127231
# Creating 2D histogram image for rows 127232 to 127487
# Creating 2D histogram image for rows 127488 to 127743
# Creating 2D histogram image for rows 127744 to 127999
# Creating 2D histogram image for rows 128000 to 128255
# Creating 2D histogram image for rows 128256 to 128511
# Creating 2D histogram image for rows 128512 to 128767
# Creating 2D histogram image for rows 128768 to 129023
# Creating 2D histogram image for rows 129024 to 129279
# Creating 2D histogram image for rows 129280 to 129535
# Creating 2D histogram image for rows 129536 to 129791
# Creating 2D histogram image for rows 129792 to 130047
# Creating 2D histogram image for rows 130048 to 130303
# Creating 2D histogram image for rows 130304 to 130559
# Creating 2D histogram image for rows 130560 to 130815
# Creating 2D histogram image for rows 130816 to 131071
# Creating 2D histogram image for rows 131072 to 131327
# Creating 2D histogram image for rows 131328 to 131583
# Creating 2D histogram image for rows 131584 to 131839
# Creating 2D histogram image for rows 131840 to 132095
# Creating 2D histogram image for rows 132096 to 132351
# Creating 2D histogram image for rows 132352 to 132607
# Creating 2D histogram image for rows 132608 to 132863
# Creating 2D histogram image for rows 132864 to 133119
# Creating 2D histogram image for rows 133120 to 133375
# Creating 2D histogram image for rows 133376 to 133631
# Creating 2D histogram image for rows 133632 to 133887
# Creating 2D histogram image for rows 133888 to 134143
# Creating 2D histogram image for rows 134144 to 134399
# Creating 2D histogram image for rows 134400 to 134655
# Creating 2D histogram image for rows 134656 to 134911
# Creating 2D histogram image for rows 134912 to 135167
# Creating 2D histogram image for rows 135168 to 135423
# Creating 2D histogram image for rows 135424 to 135679
# Creating 2D histogram image for rows 135680 to 135935
# Creating 2D histogram image for rows 135936 to 136191
# Creating 2D histogram image for rows 136192 to 136447
# Creating 2D histogram image for rows 136448 to 136703
# Creating 2D histogram image for rows 136704 to 136959
# Creating 2D histogram image for rows 136960 to 137215
# Creating 2D histogram image for rows 137216 to 137471
# Creating 2D histogram image for rows 137472 to 137727
# Creating 2D histogram image for rows 137728 to 137983
# Creating 2D histogram image for rows 137984 to 138239
# Creating 2D histogram image for rows 138240 to 138495
# Creating 2D histogram image for rows 138496 to 138751
# Creating 2D histogram image for rows 138752 to 139007
# Creating 2D histogram image for rows 139008 to 139263
# Creating 2D histogram image for rows 139264 to 139519
# Creating 2D histogram image for rows 139520 to 139775
# Creating 2D histogram image for rows 139776 to 140031
# Creating 2D histogram image for rows 140032 to 140287
# Creating 2D histogram image for rows 140288 to 140543
# Creating 2D histogram image for rows 140544 to 140799
# Creating 2D histogram image for rows 140800 to 141055
# Creating 2D histogram image for rows 141056 to 141311
# Creating 2D histogram image for rows 141312 to 141567
# Creating 2D histogram image for rows 141568 to 141823
# Creating 2D histogram image for rows 141824 to 142079
# Creating 2D histogram image for rows 142080 to 142335
# Creating 2D histogram image for rows 142336 to 142591
# Creating 2D histogram image for rows 142592 to 142847
# Creating 2D histogram image for rows 142848 to 143103
# Creating 2D histogram image for rows 143104 to 143359
# Creating 2D histogram image for rows 143360 to 143615
# Creating 2D histogram image for rows 143616 to 143871
# Creating 2D histogram image for rows 143872 to 144127
# Creating 2D histogram image for rows 144128 to 144383
# Creating 2D histogram image for rows 144384 to 144639
# Creating 2D histogram image for rows 144640 to 144895
# Creating 2D histogram image for rows 144896 to 145151
# Creating 2D histogram image for rows 145152 to 145407
# Creating 2D histogram image for rows 145408 to 145663
# Creating 2D histogram image for rows 145664 to 145919
# Creating 2D histogram image for rows 145920 to 146175
# Creating 2D histogram image for rows 146176 to 146431
# Creating 2D histogram image for rows 146432 to 146687
# Creating 2D histogram image for rows 146688 to 146943
# Creating 2D histogram image for rows 146944 to 147199
# Creating 2D histogram image for rows 147200 to 147455
# Creating 2D histogram image for rows 147456 to 147711
# Creating 2D histogram image for rows 147712 to 147967
# Creating 2D histogram image for rows 147968 to 148223
# Creating 2D histogram image for rows 148224 to 148479
# Creating 2D histogram image for rows 148480 to 148735
# Creating 2D histogram image for rows 148736 to 148991
# Creating 2D histogram image for rows 148992 to 149247
# Creating 2D histogram image for rows 149248 to 149503
# Creating 2D histogram image for rows 149504 to 149759
# Creating 2D histogram image for rows 149760 to 150015
# Creating 2D histogram image for rows 150016 to 150271
# Creating 2D histogram image for rows 150272 to 150527
# Creating 2D histogram image for rows 150528 to 150783
# Creating 2D histogram image for rows 150784 to 151039
# Creating 2D histogram image for rows 151040 to 151295
# Creating 2D histogram image for rows 151296 to 151551
# Creating 2D histogram image for rows 151552 to 151807
# Creating 2D histogram image for rows 151808 to 152063
# Creating 2D histogram image for rows 152064 to 152319
# Creating 2D histogram image for rows 152320 to 152575
# Creating 2D histogram image for rows 152576 to 152831
# Creating 2D histogram image for rows 152832 to 153087
# Creating 2D histogram image for rows 153088 to 153343
# Creating 2D histogram image for rows 153344 to 153599
# Creating 2D histogram image for rows 153600 to 153855
# Creating 2D histogram image for rows 153856 to 154111
# Creating 2D histogram image for rows 154112 to 154367
# Creating 2D histogram image for rows 154368 to 154623
# Creating 2D histogram image for rows 154624 to 154879
# Creating 2D histogram image for rows 154880 to 155135
# Creating 2D histogram image for rows 155136 to 155391
# Creating 2D histogram image for rows 155392 to 155647
# Creating 2D histogram image for rows 155648 to 155903
# Creating 2D histogram image for rows 155904 to 156159
# Creating 2D histogram image for rows 156160 to 156415
# Creating 2D histogram image for rows 156416 to 156671
# Creating 2D histogram image for rows 156672 to 156927
# Creating 2D histogram image for rows 156928 to 157183
# Creating 2D histogram image for rows 157184 to 157439
# Creating 2D histogram image for rows 157440 to 157695
# Creating 2D histogram image for rows 157696 to 157951
# Creating 2D histogram image for rows 157952 to 158207
# Creating 2D histogram image for rows 158208 to 158463
# Creating 2D histogram image for rows 158464 to 158719
# Creating 2D histogram image for rows 158720 to 158975
# Creating 2D histogram image for rows 158976 to 159231
# Creating 2D histogram image for rows 159232 to 159487
# Creating 2D histogram image for rows 159488 to 159743
# Creating 2D histogram image for rows 159744 to 159999
# Creating 2D histogram image for rows 160000 to 160255
# Creating 2D histogram image for rows 160256 to 160511
# Creating 2D histogram image for rows 160512 to 160767
# Creating 2D histogram image for rows 160768 to 161023
# Creating 2D histogram image for rows 161024 to 161279
# Creating 2D histogram image for rows 161280 to 161535
# Creating 2D histogram image for rows 161536 to 161791
# Creating 2D histogram image for rows 161792 to 162047
# Creating 2D histogram image for rows 162048 to 162303
# Creating 2D histogram image for rows 162304 to 162559
# Creating 2D histogram image for rows 162560 to 162815
# Creating 2D histogram image for rows 162816 to 162991

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

file_path = r"T_RPM_raw.npy"
data = np.load(file_path)

output_folder = r"T_RPM_histograms"
os.makedirs(output_folder, exist_ok=True)

rows_per_image = 256
num_rows = data.shape[0]

for start_idx in range(0, num_rows, rows_per_image):
    end_idx = min(start_idx + rows_per_image, num_rows)
    combined_data = data[start_idx:end_idx]

    print(f"Creating 2D histogram image for rows {start_idx} to {end_idx - 1}")
    
    combined_data_normalized = combined_data.astype(np.float32)
    combined_data_max = combined_data_normalized.max(axis=0)
    combined_data_max[combined_data_max == 0] = 1
    combined_data_normalized /= combined_data_max

    combined_data_normalized *= 255
    combined_data_normalized = combined_data_normalized.astype(np.uint8)

    plt.figure(figsize=(100, 100))
    plt.imshow(combined_data_normalized, cmap='binary', aspect='auto', interpolation='nearest')

    output_file = os.path.join(output_folder, f"2d_histogram_{start_idx}_{end_idx - 1}.png")
    plt.savefig(output_file, bbox_inches='tight', pad_inches=0)
    plt.close()
# Out:
# Creating 2D histogram image for rows 0 to 255
# Creating 2D histogram image for rows 256 to 511
# Creating 2D histogram image for rows 512 to 767
# Creating 2D histogram image for rows 768 to 1023
# Creating 2D histogram image for rows 1024 to 1279
# Creating 2D histogram image for rows 1280 to 1535
# Creating 2D histogram image for rows 1536 to 1791
# Creating 2D histogram image for rows 1792 to 2047
# Creating 2D histogram image for rows 2048 to 2303
# Creating 2D histogram image for rows 2304 to 2559
# Creating 2D histogram image for rows 2560 to 2815
# Creating 2D histogram image for rows 2816 to 3071
# Creating 2D histogram image for rows 3072 to 3327
# Creating 2D histogram image for rows 3328 to 3583
# Creating 2D histogram image for rows 3584 to 3839
# Creating 2D histogram image for rows 3840 to 4095
# Creating 2D histogram image for rows 4096 to 4351
# Creating 2D histogram image for rows 4352 to 4607
# Creating 2D histogram image for rows 4608 to 4863
# Creating 2D histogram image for rows 4864 to 5119
# Creating 2D histogram image for rows 5120 to 5375
# Creating 2D histogram image for rows 5376 to 5631
# Creating 2D histogram image for rows 5632 to 5887
# Creating 2D histogram image for rows 5888 to 6143
# Creating 2D histogram image for rows 6144 to 6399
# Creating 2D histogram image for rows 6400 to 6655
# Creating 2D histogram image for rows 6656 to 6911
# Creating 2D histogram image for rows 6912 to 7167
# Creating 2D histogram image for rows 7168 to 7423
# Creating 2D histogram image for rows 7424 to 7679
# Creating 2D histogram image for rows 7680 to 7935
# Creating 2D histogram image for rows 7936 to 8191
# Creating 2D histogram image for rows 8192 to 8447
# Creating 2D histogram image for rows 8448 to 8703
# Creating 2D histogram image for rows 8704 to 8959
# Creating 2D histogram image for rows 8960 to 9215
# Creating 2D histogram image for rows 9216 to 9471
# Creating 2D histogram image for rows 9472 to 9727
# Creating 2D histogram image for rows 9728 to 9983
# Creating 2D histogram image for rows 9984 to 10239
# Creating 2D histogram image for rows 10240 to 10495
# Creating 2D histogram image for rows 10496 to 10751
# Creating 2D histogram image for rows 10752 to 11007
# Creating 2D histogram image for rows 11008 to 11263
# Creating 2D histogram image for rows 11264 to 11519
# Creating 2D histogram image for rows 11520 to 11775
# Creating 2D histogram image for rows 11776 to 12031
# Creating 2D histogram image for rows 12032 to 12287
# Creating 2D histogram image for rows 12288 to 12543
# Creating 2D histogram image for rows 12544 to 12799
# Creating 2D histogram image for rows 12800 to 13055
# Creating 2D histogram image for rows 13056 to 13311
# Creating 2D histogram image for rows 13312 to 13567
# Creating 2D histogram image for rows 13568 to 13823
# Creating 2D histogram image for rows 13824 to 14079
# Creating 2D histogram image for rows 14080 to 14335
# Creating 2D histogram image for rows 14336 to 14591
# Creating 2D histogram image for rows 14592 to 14847
# Creating 2D histogram image for rows 14848 to 15103
# Creating 2D histogram image for rows 15104 to 15359
# Creating 2D histogram image for rows 15360 to 15615
# Creating 2D histogram image for rows 15616 to 15871
# Creating 2D histogram image for rows 15872 to 16127
# Creating 2D histogram image for rows 16128 to 16383
# Creating 2D histogram image for rows 16384 to 16639
# Creating 2D histogram image for rows 16640 to 16895
# Creating 2D histogram image for rows 16896 to 17151
# Creating 2D histogram image for rows 17152 to 17407
# Creating 2D histogram image for rows 17408 to 17663
# Creating 2D histogram image for rows 17664 to 17919
# Creating 2D histogram image for rows 17920 to 18175
# Creating 2D histogram image for rows 18176 to 18431
# Creating 2D histogram image for rows 18432 to 18687
# Creating 2D histogram image for rows 18688 to 18943
# Creating 2D histogram image for rows 18944 to 19199
# Creating 2D histogram image for rows 19200 to 19455
# Creating 2D histogram image for rows 19456 to 19711
# Creating 2D histogram image for rows 19712 to 19967
# Creating 2D histogram image for rows 19968 to 20223
# Creating 2D histogram image for rows 20224 to 20479
# Creating 2D histogram image for rows 20480 to 20735
# Creating 2D histogram image for rows 20736 to 20991
# Creating 2D histogram image for rows 20992 to 21247
# Creating 2D histogram image for rows 21248 to 21503
# Creating 2D histogram image for rows 21504 to 21759
# Creating 2D histogram image for rows 21760 to 22015
# Creating 2D histogram image for rows 22016 to 22271
# Creating 2D histogram image for rows 22272 to 22527
# Creating 2D histogram image for rows 22528 to 22783
# Creating 2D histogram image for rows 22784 to 23039
# Creating 2D histogram image for rows 23040 to 23295
# Creating 2D histogram image for rows 23296 to 23551
# Creating 2D histogram image for rows 23552 to 23807
# Creating 2D histogram image for rows 23808 to 24063
# Creating 2D histogram image for rows 24064 to 24319
# Creating 2D histogram image for rows 24320 to 24575
# Creating 2D histogram image for rows 24576 to 24831
# Creating 2D histogram image for rows 24832 to 25087
# Creating 2D histogram image for rows 25088 to 25343
# Creating 2D histogram image for rows 25344 to 25599
# Creating 2D histogram image for rows 25600 to 25855
# Creating 2D histogram image for rows 25856 to 26111
# Creating 2D histogram image for rows 26112 to 26367
# Creating 2D histogram image for rows 26368 to 26623
# Creating 2D histogram image for rows 26624 to 26879
# Creating 2D histogram image for rows 26880 to 27135
# Creating 2D histogram image for rows 27136 to 27391
# Creating 2D histogram image for rows 27392 to 27647
# Creating 2D histogram image for rows 27648 to 27903
# Creating 2D histogram image for rows 27904 to 28159
# Creating 2D histogram image for rows 28160 to 28415
# Creating 2D histogram image for rows 28416 to 28671
# Creating 2D histogram image for rows 28672 to 28927
# Creating 2D histogram image for rows 28928 to 29183
# Creating 2D histogram image for rows 29184 to 29439
# Creating 2D histogram image for rows 29440 to 29695
# Creating 2D histogram image for rows 29696 to 29951
# Creating 2D histogram image for rows 29952 to 30207
# Creating 2D histogram image for rows 30208 to 30463
# Creating 2D histogram image for rows 30464 to 30719
# Creating 2D histogram image for rows 30720 to 30975
# Creating 2D histogram image for rows 30976 to 31231
# Creating 2D histogram image for rows 31232 to 31487
# Creating 2D histogram image for rows 31488 to 31743
# Creating 2D histogram image for rows 31744 to 31999
# Creating 2D histogram image for rows 32000 to 32255
# Creating 2D histogram image for rows 32256 to 32511
# Creating 2D histogram image for rows 32512 to 32767
# Creating 2D histogram image for rows 32768 to 33023
# Creating 2D histogram image for rows 33024 to 33279
# Creating 2D histogram image for rows 33280 to 33535
# Creating 2D histogram image for rows 33536 to 33791
# Creating 2D histogram image for rows 33792 to 34047
# Creating 2D histogram image for rows 34048 to 34303
# Creating 2D histogram image for rows 34304 to 34559
# Creating 2D histogram image for rows 34560 to 34815
# Creating 2D histogram image for rows 34816 to 35071
# Creating 2D histogram image for rows 35072 to 35327
# Creating 2D histogram image for rows 35328 to 35583
# Creating 2D histogram image for rows 35584 to 35839
# Creating 2D histogram image for rows 35840 to 36095
# Creating 2D histogram image for rows 36096 to 36351
# Creating 2D histogram image for rows 36352 to 36607
# Creating 2D histogram image for rows 36608 to 36863
# Creating 2D histogram image for rows 36864 to 37007

# %%
import numpy as np

def process_txt_to_npy(file_path, output_file):
    """
    Process a .txt file containing traffic data and save the data payloads to a single .npy file.

    :param file_path: Path to the input .txt file.
    :param output_file: Path to the output .npy file.
    """
    payloads = []

    try:
        with open(file_path, 'r') as file:
            for line in file:
                try:
                    # Split the line into parts based on spaces
                    parts = line.split()
                    
                    # Extract the DLC (Data Length Code) and Payload
                    dlc_index = parts.index('DLC:') + 1
                    dlc = int(parts[dlc_index])
                    payload_start = dlc_index + 1
                    payload = parts[payload_start:payload_start + dlc]

                    # Convert payload from hex to integers
                    payload_int = [int(byte, 16) for byte in payload]
                    payloads.append(payload_int)
                except Exception as e:
                    print(f"Error parsing line: {line.strip()} - {e}")
                    continue

        # Convert the list of payloads to a NumPy array
        payload_array = np.array(payloads, dtype=object)  # Use object for varying payload lengths

        # Save the array to an .npy file
        np.save(output_file, payload_array)
        print(f"Data successfully saved to {output_file}")
        print(f"Processed {len(payloads)} entries.")

    except FileNotFoundError:
        print("The specified file was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")


if __name__ == '__main__':
    input_file = r"normal_run_data.txt"  # Replace with the actual .txt file path
    output_file = r"normal_run_data.npy"  # Desired output .npy file name
    process_txt_to_npy(input_file, output_file)
